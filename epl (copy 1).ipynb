# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("results.csv", encoding = 'unicode_escape')

# %%
data.sample(5)
# Out:
#        Season              DateTime        HomeTeam        AwayTeam  FTHG  \
# 7844  2013-14  2013-10-26T00:00:00Z     Aston Villa         Everton     0
# 7714  2012-13  2013-04-20T00:00:00Z      Sunderland         Everton     1
# 9027  2016-17  2016-11-26T00:00:00Z       Leicester   Middlesbrough     2
# 1846  1997-98  1997-12-06T00:00:00Z       Leicester  Crystal Palace     1
# 989   1995-96  1995-09-23T00:00:00Z  Sheffield Weds      Man United     0
#
#       FTAG FTR  HTHG  HTAG HTR  ...  HST  AST   HC    AC    HF    AF   HY  \
# 7844     2   A   0.0   0.0   D  ...  3.0  4.0  8.0   6.0  14.0   8.0  0.0
# 7714     0   H   1.0   0.0   H  ...  4.0  5.0  3.0  10.0   6.0  15.0  1.0
# 9027     2   D   1.0   1.0   D  ...  3.0  2.0  2.0   3.0  15.0  12.0  4.0
# 1846     1   D   0.0   1.0   A  ...  NaN  NaN  NaN   NaN   NaN   NaN  NaN
# 989      0   D   0.0   0.0   D  ...  NaN  NaN  NaN   NaN   NaN   NaN  NaN
#
#        AY   HR   AR
# 7844  2.0  0.0  0.0
# 7714  2.0  0.0  0.0
# ...

# %%
data.shape
# Out:
# (11113, 23)

# %% [markdown]
# ## There are 11113 data entries and 23 features

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11113 entries, 0 to 11112
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Season    11113 non-null  object
#  1   DateTime  11113 non-null  object
#  2   HomeTeam  11113 non-null  object
#  3   AwayTeam  11113 non-null  object
#  4   FTHG      11113 non-null  int64
#  5   FTAG      11113 non-null  int64
#  6   FTR       11113 non-null  object
#  7   HTHG      10189 non-null  float64
#  8   HTAG      10189 non-null  float64
#  9   HTR       10189 non-null  object
#  10  Referee   8289 non-null   object
#  11  HS        8289 non-null   float64
#  12  AS        8289 non-null   float64
#  13  HST       8289 non-null   float64
#  14  AST       8289 non-null   float64
#  15  HC        8289 non-null   float64
#  16  AC        8289 non-null   float64
#  17  HF        8289 non-null   float64
#  18  AF        8289 non-null   float64
# ...

# %%
data_cleaned = data.dropna()

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8289 entries, 2824 to 11112
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Season    8289 non-null   object
#  1   DateTime  8289 non-null   object
#  2   HomeTeam  8289 non-null   object
#  3   AwayTeam  8289 non-null   object
#  4   FTHG      8289 non-null   int64
#  5   FTAG      8289 non-null   int64
#  6   FTR       8289 non-null   object
#  7   HTHG      8289 non-null   float64
#  8   HTAG      8289 non-null   float64
#  9   HTR       8289 non-null   object
#  10  Referee   8289 non-null   object
#  11  HS        8289 non-null   float64
#  12  AS        8289 non-null   float64
#  13  HST       8289 non-null   float64
#  14  AST       8289 non-null   float64
#  15  HC        8289 non-null   float64
#  16  AC        8289 non-null   float64
#  17  HF        8289 non-null   float64
#  18  AF        8289 non-null   float64
# ...

# %%
data_cleaned.sample(5)
# Out:
#        Season              DateTime     HomeTeam     AwayTeam  FTHG  FTAG FTR  \
# 7424  2012-13  2012-09-22T00:00:00Z  Southampton  Aston Villa     4     1   H
# 7120  2011-12  2011-11-19T00:00:00Z        Wigan    Blackburn     3     3   D
# 9394  2017-18  2017-11-18T00:00:00Z      Arsenal    Tottenham     2     0   H
# 3740  2002-03  2002-12-01T00:00:00Z    Liverpool   Man United     1     2   A
# 5239  2006-07  2006-11-26T00:00:00Z   Man United      Chelsea     1     1   D
#
#       HTHG  HTAG HTR  ...   HST  AST   HC   AC    HF    AF   HY   AY   HR   AR
# 7424   0.0   1.0   A  ...   4.0  2.0  1.0  4.0   5.0  13.0  1.0  3.0  0.0  0.0
# 7120   2.0   1.0   H  ...  11.0  2.0  7.0  3.0  14.0  13.0  2.0  3.0  0.0  1.0
# 9394   2.0   0.0   H  ...   5.0  4.0  7.0  4.0  11.0  16.0  4.0  1.0  0.0  0.0
# 3740   0.0   0.0   D  ...   7.0  4.0  5.0  2.0  13.0  11.0  1.0  4.0  0.0  0.0
# 5239   1.0   0.0   H  ...   5.0  7.0  3.0  2.0  16.0  12.0  1.0  3.0  0.0  0.0
#
# [5 rows x 23 columns]

# %%
data_cleaned.head(5)
# Out:
#        Season              DateTime  HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 2824  2000-01  2000-08-19T00:00:00Z  Charlton       Man City     4     0   H
# 2825  2000-01  2000-08-19T00:00:00Z   Chelsea       West Ham     4     2   H
# 2826  2000-01  2000-08-19T00:00:00Z  Coventry  Middlesbrough     1     3   A
# 2827  2000-01  2000-08-19T00:00:00Z     Derby    Southampton     2     2   D
# 2828  2000-01  2000-08-19T00:00:00Z     Leeds        Everton     2     0   H
#
#       HTHG  HTAG HTR  ...   HST  AST   HC   AC    HF    AF   HY   AY   HR   AR
# 2824   2.0   0.0   H  ...  14.0  4.0  6.0  6.0  13.0  12.0  1.0  2.0  0.0  0.0
# 2825   1.0   0.0   H  ...  10.0  5.0  7.0  7.0  19.0  14.0  1.0  2.0  0.0  0.0
# 2826   1.0   1.0   D  ...   3.0  9.0  8.0  4.0  15.0  21.0  5.0  3.0  1.0  0.0
# 2827   1.0   2.0   A  ...   4.0  6.0  5.0  8.0  11.0  13.0  1.0  1.0  0.0  0.0
# 2828   2.0   0.0   H  ...   8.0  6.0  6.0  4.0  21.0  20.0  1.0  3.0  0.0  0.0
#
# [5 rows x 23 columns]

# %%
data_cleaned.shape
# Out:
# (8289, 23)

# %%
data_cleaned['Month'] = pd.DatetimeIndex(data_cleaned['DateTime']).month
data_cleaned['Day'] = pd.DatetimeIndex(data_cleaned['DateTime']).day
data_cleaned = data_cleaned.drop('DateTime', axis = 1)
data_cleaned.head()
# Out:
# /tmp/ipykernel_120292/2579618903.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Month'] = pd.DatetimeIndex(data_cleaned['DateTime']).month
# /tmp/ipykernel_120292/2579618903.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Day'] = pd.DatetimeIndex(data_cleaned['DateTime']).day
#        Season  HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 2824  2000-01  Charlton       Man City     4     0   H   2.0   0.0   H
# ...

# %% [markdown]
# ## EDA

# %%
data_cleaned.describe(include=['O'])
# Out:
#          Season    HomeTeam   AwayTeam   FTR   HTR Referee
# count      8289        8289       8289  8289  8289    8289
# unique       22          44         44     3     3     158
# top     2000-01  Man United  Liverpool     H     D  M Dean
# freq        380         415        415  3803  3420     523

# %% [markdown]
# There are 44 unique teams, 22 seasons and 158 refrees.

# %%
data_cleaned.describe()
# Out:
#               FTHG         FTAG         HTHG         HTAG           HS  \
# count  8289.000000  8289.000000  8289.000000  8289.000000  8289.000000
# mean      1.519242     1.155507     0.681506     0.506816    13.503921
# std       1.299000     1.142826     0.831712     0.723624     5.258636
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000     0.000000    10.000000
# 50%       1.000000     1.000000     0.000000     0.000000    13.000000
# 75%       2.000000     2.000000     1.000000     1.000000    17.000000
# max       9.000000     9.000000     5.000000     5.000000    43.000000
#
#                 AS          HST          AST           HC           AC  \
# count  8289.000000  8289.000000  8289.000000  8289.000000  8289.000000
# mean     10.644589     6.117264     4.768247     6.081795     4.784292
# std       4.583010     3.327521     2.792965     3.095070     2.728954
# ...

# %%
data_cleaned.dtypes
# Out:
# Season       object
# HomeTeam     object
# AwayTeam     object
# FTHG          int64
# FTAG          int64
# FTR          object
# HTHG        float64
# HTAG        float64
# HTR          object
# Referee      object
# HS          float64
# AS          float64
# HST         float64
# AST         float64
# HC          float64
# AC          float64
# HF          float64
# AF          float64
# HY          float64
# AY          float64
# HR          float64
# AR          float64
# Month         int64
# Day           int64
# dtype: object
